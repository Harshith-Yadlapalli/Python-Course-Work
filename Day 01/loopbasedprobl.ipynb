# %%
l=[10,5,65,35,90,95,99]
max=l[4]
for i in l:
    if i>=max:
        max=i
print(max)
# Out:
# 99

# %%
l=[10,5,65,35,40,90,95]
max=float('-inf')
for i in l:
    if i>=max:
        max=i
print(max)
# Out:
# 95

# %%
l=[-10,-5,-65,-35,-40,-90,-95]
max=float('-inf')
for i in l:
    if i>=max:
        max=i
print(max)
# Out:
# -5

# %%
l=[-10,-5,-65,-35,-40,-90,-95]
max=l[0]
for i in l:
    if i>=max:
        max=i
print(max)
# Out:
# 0

# %%
l=[-2,-77,74]
max=float('-inf')
for i in l:
    if i>max:
        max=i
        print(max)
# Out:
# -2
# 74

# %%
l = [-2,-77,74,0,7,18,5,33,22,34]
first = second = float('-inf')
for num in l:
    if num > first:
        second = first 
        first = num
    elif num>second and num<first:
        second = num
print(first)
print(num)
# Out:
# 74
# 34

# %%
l = [-2, -77, 74, 0, 7, 18, 5, 33, 22, 34]
first = second = third = float('-inf')
for num in l:
    if num > first:
        third = second
        second = first
        first = num
    elif num > second:
        third = second
        second = num
    elif num > third:
        third = num
print(first)
print(second)
print(third)
# Out:
# 74
# 34
# 33

# %%
l = [-2, -77, 74, 0, 7, 18, 5, 33, 22, 34]
first = second = third = 0
for num in l:
    if num > first:
        third = second
        second = first
        first = num
    elif num > second:
        third = second
        second = num
    elif num > third:
        third = num
print(first)
print(second)
print(third)
# Out:
# 74
# 34
# 33
